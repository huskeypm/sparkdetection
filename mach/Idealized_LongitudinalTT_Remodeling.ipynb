# %% [markdown]
# #Notebook to see response of filter for TT with longitudinal remodeling

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import cv2
import util
import scipy.fftpack as fftp
import mach
import copy
import matchedFilter as mF

# %%
root = "./images/"

# %% [markdown]
# ### Read in idealized longitudinal image and corresponding filter

# %%
RawRoot = root+"Remodeled_TTs/"
idealLongName = "TT_Idealized_Longitudinal.png"
idealImg = util.ReadImg(RawRoot+idealLongName)

# %%
util.myplot(idealImg)

# %%
truthFilterName = "TT_Idealized_Longitudinal_Filter.png"
truthFilter = util.ReadImg(RawRoot+truthFilterName)

# %%
util.myplot(truthFilter)

# %% [markdown]
# ### Images need to be inverted for proper filter response

# %%
retval, newImg = cv2.threshold(idealImg, 150,255, cv2.THRESH_BINARY_INV)
newImg /= np.max(newImg)
util.myplot(newImg)

# %%
# cutting out the borders since the image saved much larger than anticipated
#longImg = newImg[135:350,150:830]
longImg = newImg[100:400,100:870]
longImg[0:40] = 0
longImg[260:] = 0
longImg[:,0:60] = 0
longImg[:,715:] = 0
imshow(longImg)
plt.figure()
util.myplot(longImg)

# %%
retval2, newFilter = cv2.threshold(truthFilter, 150, 255, cv2.THRESH_BINARY_INV)
newFilter /= np.max(newFilter)
imshow(newFilter)

# %% [markdown]
# ### Filtering

# %%
h = mF.matchedFilter(longImg,newFilter,demean=False)

# %%
util.myplot(h)

# %%
#print type(h[0,0])
#print h
if np.min(h) < 0:
    h = h - np.min(h)
else:
    h = h + np.min(h)
print np.max(h)

h = h * 255. / np.max(h)

#h = h.astype(np.uint8)
print type(h[0,0])
print h
imshow(h)
plt.colorbar()
# Out:
# 640.0
# <type 'numpy.float64'>
# [[  4.77275045e-14   6.25517646e-14   4.68420540e-14 ...,   4.45632827e-14
#     5.38527606e-14   4.89863864e-14]
#  [  4.85216408e-14   6.34489692e-14   4.70990751e-14 ...,   4.49200022e-14
#     5.43590648e-14   4.97596723e-14]
#  [  4.78312498e-14   6.32274783e-14   4.61540092e-14 ...,   4.46559701e-14
#     5.40801981e-14   4.95400155e-14]
#  ...,
#  [  4.89161299e-14   6.37503480e-14   4.80720361e-14 ...,   4.56474747e-14
#     5.53065399e-14   4.98266610e-14]
#  [  4.80897486e-14   6.27914907e-14   4.75579411e-14 ...,   4.48482581e-14
#     5.45346338e-14   4.92507366e-14]
#  [  4.85158978e-14   6.31562117e-14   4.80225527e-14 ...,   4.50369722e-14
#     5.49236358e-14   4.96367650e-14]]

# %%
thresher = h.copy()
thresher[h < (0.95 * np.max(h))] = 0
plt.figure()
imshow(thresher,cmap='gray')

# %% [markdown]
# # PERFECT
