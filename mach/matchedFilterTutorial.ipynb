# %% [markdown]
# # Matched Filter Tutorial Script
#
# The purpose of this script is to demonstrate some key concepts of the matched filtering routine

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matchedFilter as mF

# %% [markdown]
# ### Make Three Sizes of Images

# %%
bigImg = np.zeros((300,300))
img = np.zeros((200,200))
smallImg = np.zeros((100,100))

# %%
bigImg[150, 120:180] = 1
plt.figure()
imshow(bigImg)

img[100, 70:130] = 1
plt.figure()
imshow(img)

smallImg[50, 20:80] = 1
plt.figure()
imshow(smallImg)


imgDict = {}
imgDict['big'] = bigImg
imgDict['norm'] = img
imgDict['small'] = smallImg

# %% [markdown]
# ### Make Three Sizes of Filters

# %%
bigFilter = np.zeros((60,66))
bigFilter[29:31,3:-3] = 1
plt.figure()
imshow(bigFilter)

Filter = np.zeros((40, 66))
Filter[19:21,3:-3] = 1
plt.figure()
imshow(Filter)


smallFilter = np.zeros((20,66))
smallFilter[9:11,3:-3] = 1
plt.figure()
imshow(smallFilter)

filterDict = {}
filterDict['big'] = bigFilter
filterDict['norm'] = Filter
filterDict['small'] = smallFilter

# %%
for size, img in imgDict.iteritems():
    for size2, myFilter in filterDict.iteritems():
        response = mF.matchedFilter(img, myFilter)
        plt.figure()
        imshow(response,cmap='gray')
        plt.title("img size "+size+" filter size "+size2)
        plt.colorbar()
        print "Image Size:", size, "\tFilter Size:", size2
        print "Minimum Response =", np.min(response), "\t", "Maximum Response =", np.max(response), "\t", "Average Response =", np.mean(response)
        print 120*"#", "\n"
# Out:
# Image Size: small 	Filter Size: small
# Minimum Response = -7.2e-05 	Maximum Response = 0.005928 	Average Response = -5.55111512313e-21
# ########################################################################################################################
#
# Image Size:
#  small 	Filter Size: big
# Minimum Response = -7.2e-05 	Maximum Response = 0.005928 	Average Response = -5.55111512313e-21
# ########################################################################################################################
#
# Image Size:
#  small 	Filter Size: norm
# Minimum Response = -7.2e-05 	Maximum Response = 0.005928 	Average Response = -5.55111512313e-21
# ########################################################################################################################
#
# Image Size:
#  big 	Filter Size: small
# Minimum Response = -8.88888888889e-07 	Maximum Response = 0.000665777777778 	Average Response = 2.89120579329e-23
# ########################################################################################################################
#
# Image Size:
#  big 	Filter Size: big
# Minimum Response = -8.88888888889e-07 	Maximum Response = 0.000665777777778 	Average Response = 2.89120579329e-23
# ########################################################################################################################
#
# Image Size:
#  big 	Filter Size: norm
# Minimum Response = -8.88888888889e-07 	Maximum Response = 0.000665777777778 	Average Response = 2.89120579329e-23
# ########################################################################################################################
#
# Image Size:
#  norm 	Filter Size: small
# Minimum Response = -4.5e-06 	Maximum Response = 0.0014955 	Average Response = 0.0
# ########################################################################################################################
#
# Image Size:
#  norm 	Filter Size: big
# Minimum Response = -4.5e-06 	Maximum Response = 0.0014955 	Average Response = 0.0
# ########################################################################################################################
#
# Image Size:
#  norm 	Filter Size: norm
# Minimum Response = -4.5e-06 	Maximum Response = 0.0014955 	Average Response = 0.0
# ########################################################################################################################

# %% [markdown]
# ### Testing filters that are longer and shorter

# %%
longFilter = np.zeros((60,100))
longFilter[29:31,20:80] = 1
plt.figure()
imshow(longFilter)

medFilter = np.zeros((40, 80))
medFilter[19:21,10:70] = 1
plt.figure()
imshow(medFilter)


shortFilter = np.zeros((20,66))
shortFilter[9:11,3:-3] = 1
plt.figure()
imshow(shortFilter)

filterDictHoriz = {}
filterDictHoriz['long'] = longFilter
filterDictHoriz['med'] = medFilter
filterDictHoriz['short'] = shortFilter

# %%
for size, img in imgDict.iteritems():
    for size2, myFilter in filterDictHoriz.iteritems():
        response = mF.matchedFilter(img, myFilter)
        plt.figure()
        imshow(response,cmap='gray')
        plt.title("img size "+size+" filter size "+size2)
        plt.colorbar()
        #print 50*"#"
        print "Image Size:", size, "\tFilter Size:", size2
        print "Minimum Response =", np.min(response), "\t", "Maximum Response =", np.max(response), "\t", "Average Response =", np.mean(response)
        print 120*"#", "\n"
# Out:
# Image Size: small 	Filter Size: med
# Minimum Response = -7.2e-05 	Maximum Response = 0.005928 	Average Response = -5.55111512313e-21
# ########################################################################################################################
#
# Image Size:
#  small 	Filter Size: short
# Minimum Response = -7.2e-05 	Maximum Response = 0.005928 	Average Response = -5.55111512313e-21
# ########################################################################################################################
#
# Image Size:
#  small 	Filter Size: long
# Minimum Response = -7.2e-05 	Maximum Response = 0.005928 	Average Response = -5.55111512313e-21
# ########################################################################################################################
#
# Image Size:
#  big 	Filter Size: med
# Minimum Response = -8.88888888889e-07 	Maximum Response = 0.000665777777778 	Average Response = 2.89120579329e-23
# ########################################################################################################################
#
# Image Size:
#  big 	Filter Size: short
# Minimum Response = -8.88888888889e-07 	Maximum Response = 0.000665777777778 	Average Response = 2.89120579329e-23
# ########################################################################################################################
#
# Image Size:
#  big 	Filter Size: long
# Minimum Response = -8.88888888889e-07 	Maximum Response = 0.000665777777778 	Average Response = 2.89120579329e-23
# ########################################################################################################################
#
# Image Size:
#  norm 	Filter Size: med
# Minimum Response = -4.5e-06 	Maximum Response = 0.0014955 	Average Response = 0.0
# ########################################################################################################################
#
# Image Size:
#  norm 	Filter Size: short
# Minimum Response = -4.5e-06 	Maximum Response = 0.0014955 	Average Response = 0.0
# ########################################################################################################################
#
# Image Size:
#  norm 	Filter Size: long
# Minimum Response = -4.5e-06 	Maximum Response = 0.0014955 	Average Response = 0.0
# ########################################################################################################################

# %% [markdown]
# ### Conclusions From Above
#
#  - It can be seen that the amount of blank space in the filter does not effect the response.
#  - It is also shown that the amount of blank space in the image does effect the response
#   - Due to the average response being defined as 0 (within computational limits).

# %%
crowdedImg = imgDict['norm'].copy()
# bar is located at 100, so let's put some pixels to the upper right of it and see how each filter responds
# spacing bar so that it is out of the range of the small filter but still within range of larger filters
rowIndex = 100 - int(np.shape(filterDict['small'])[0]) - 5
print rowIndex
crowdedImg[rowIndex, 100:160] = 1
imshow(crowdedImg)
# Out:
# 75

# %%
for sizeFilter, Filter in filterDict.iteritems():
        response = mF.matchedFilter(crowdedImg, Filter)
        plt.figure()
        imshow(response,cmap='gray')
        plt.title("Filter size "+sizeFilter)
        plt.colorbar()
        #print 50*"#"
        #print "Image Size:", size, "\tFilter Size:", size2
        print "Filter Size:", sizeFilter
        print "Minimum Response =", np.min(response), "\t", "Maximum Response =", np.max(response), "\t", "Average Response =", np.mean(response)
        print "Sum of Response Along Row of Upper Bar =", np.sum(response[rowIndex])
        print "Maximum Response Along Row of Upper Bar =", np.max(response[rowIndex])
        print 120*"#", "\n"
# Out:
# Filter Size: small
# Minimum Response = -9e-06 	Maximum Response = 0.001491 	Average Response = -1.73472347598e-21
# Sum of Response Along Row of Upper Bar = 0.0882
# Maximum Response Along Row of Upper Bar = 0.001491
# ########################################################################################################################
#
# Filter Size:
#  big
# Minimum Response = -9e-06 	Maximum Response = 0.001491 	Average Response = -1.73472347598e-21
# Sum of Response Along Row of Upper Bar = 0.0882
# Maximum Response Along Row of Upper Bar = 0.001491
# ########################################################################################################################
#
# Filter Size:
#  norm
# Minimum Response = -9e-06 	Maximum Response = 0.001491 	Average Response = -1.73472347598e-21
# Sum of Response Along Row of Upper Bar = 0.0882
# Maximum Response Along Row of Upper Bar = 0.001491
# ########################################################################################################################

# %% [markdown]
# ### Conclusions (cont.)
#
#  - The presence of the bar in the image did not effect the response of the matched filter, even when the bar to the upper right was within the range of the smallest filter
