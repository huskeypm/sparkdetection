# %% [markdown]
# ### Developing algorithm for testing/optimizing parameters

# %%
# %load_ext autoreload
# %autoreload 2  
import cv2
import bankDetect as bD
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:1352: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
fusedPSs=[]
bulkNSs=[]
bulkPSs=[]
fusedNSs=[]


fusedPS,bulkNS,bulkPS,fusedNS = optimizer.TestParams(fusedThresh=1200.,bulkThresh=1000.,sigma_n=1,display=False)
fusedPSs.append(fusedPS)
bulkNSs.append(bulkNS)
bulkPSs.append(bulkPS)
fusedNSs.append(fusedNS)



fusedPSs= np.array(fusedPSs)
bulkNSs= np.array(bulkNSs)
bulkPSs= np.array(bulkPSs)
fusedNSs= np.array(fusedNSs)
# Out:
# 984.3519 1484.335
# rot 30.0 hit 1126.2
# 1725.409 2172.8254
# rot 30.0 hit 1046.8
# 0.0
# 0.00493545937737
# 1014.4395 1477.5204
# rot  5.0 hit 1126.2
# 1723.8172 2304.3622
# rot  5.0 hit 1092.0
# 0.640973630832
# 0.0

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import optimizer

# %%
df = optimizer.Assess()
# Out:
# 984.3519 1484.335
# rot 30.0 hit 1126.2
# 1725.409 2172.8254
# rot 30.0 hit 1046.8
# 0.975322703113
# 0.257023538345
# 1014.4395 1477.5204
# rot  5.0 hit 1126.2
# 1723.8172 2304.3622
# rot  5.0 hit 1092.0
# 1.0
# 0.803245436105
# 984.3519 1484.335
# rot 30.0 hit 1126.2
# 1725.409 2172.8254
# rot 30.0 hit 1046.8
# 0.975322703113
# 0.0
# 1014.4395 1477.5204
# rot  5.0 hit 1126.2
# 1723.8172 2304.3622
# rot  5.0 hit 1092.0
# 0.0
# 0.803245436105
# 984.3519 1484.335
# rot 30.0 hit 1126.2
# 1725.409 2172.8254
# rot 30.0 hit 1046.8
# 0.975322703113
# 0.0
# 1014.4395 1477.5204
# rot  5.0 hit 1126.2
# 1723.8172 2304.3622
# rot  5.0 hit 1092.0
# 0.0
# 0.803245436105
# 984.3519 1484.335
# rot 30.0 hit 1126.2
# 1725.409 2172.8254
# rot 30.0 hit 1046.8
# 0.00873196659074
# 0.257023538345
# 1014.4395 1477.5204
# rot  5.0 hit 1126.2
# 1723.8172 2304.3622
# rot  5.0 hit 1092.0
# 1.0
# 0.0
# 984.3519 1484.335
# rot 30.0 hit 1126.2
# 1725.409 2172.8254
# rot 30.0 hit 1046.8
# 0.00873196659074
# 0.0
# ...

# %% [markdown]
# Or run offline

# %%
hdf5Name = "optimizer.h5"
df = pd.read_hdf(hdf5Name,'table')
#df

# %%
optimizer.AnalyzePerformanceData(df,tag='bulk')

# %%
optimizer.AnalyzePerformanceData(df,tag='fused')

# %%
fusedThresh=1000
bulkThresh = 933
optimizer.TestParams(fusedThresh=fusedThresh,bulkThresh=bulkThresh,sigma_n=1.,display=True)
# Out:
# 984.3519 1484.335
# rot 30.0 hit 1126.2
# 1725.409
#  2172.8254
# rot 30.0 hit 1046.8
# 1014.4395
#  1477.5204
# rot  5.0 hit 1126.2
# 1723.8172
#  2304.3622
# rot  5.0 hit 1092.0
# (0.52923310554290048,
#  0.070235383447228544,
#  0.96551724137931039,
#  0.17849898580121704)
