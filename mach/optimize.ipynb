# %% [markdown]
# ### Developing algorithm for testing/optimizing parameters

# %%
# %load_ext autoreload
# %autoreload 2  
import cv2
import bankDetect as bD
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:1352: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import optimizer

# %%
if 0:
 df = optimizer.Assess(
  #fusedThreshes = np.linspace(800,1100,3),
  fusedThreshes=[1000],
  bulkThreshes = np.linspace(800,1100,3),
  sigma_n = 1.,
  display=True
  )
    
if 1:
 df = optimizer.Assess(
  #fusedThreshes = np.linspace(800,1100,3),
  fusedThreshes=np.linspace(0.5,0.95,10),
  bulkThreshes = np.linspace(0.4,0.7,10),
  sigma_n = 1.,
  useFilterInv=True,
  display=False
  )
# Out:
# 0.5 0.4 1.0 0.0492 1.0 0.2634
# 0.5
#  0.433333333333 1.0 0.0388 1.0 0.2634
# 0.5 0.466666666667 1.0 0.0111 0.981744421907 0.2634
# 0.5
#  0.5 1.0 0.0028 0.892494929006 0.2634
# 0.5
#  0.533333333333 1.0 0.0001 0.567951318458 0.2634
# 0.5 0.566666666667 1.0 0.0 0.139959432049 0.2634
# 0.5
#  0.6 1.0 0.0 0.0 0.2634
# 0.5 0.633333333333 1.0 0.0 0.0 0.2634
# 0.5
#  0.666666666667 1.0 0.0 0.0 0.2634
# 0.5 0.7 1.0 0.0 0.0 0.2634
# 0.55
#  0.4 1.0 0.0492 1.0 0.2634
# 0.55 0.433333333333 1.0 0.0388 1.0 0.2634
# 0.55
#  0.466666666667 1.0 0.0111 0.981744421907 0.2634
# 0.55 0.5 1.0 0.0028 0.892494929006 0.2634
# 0.55
#  0.533333333333 1.0 0.0001 0.567951318458 0.2634
# 0.55 0.566666666667 1.0 0.0 0.139959432049 0.2634
# 0.55
#  0.6 1.0 0.0 0.0 0.2634
# 0.55 0.633333333333 1.0 0.0 0.0 0.2634
# 0.55
#  0.666666666667 1.0 0.0 0.0 0.2634
# 0.55 0.7 1.0 0.0 0.0 0.2634
# 0.6
#  0.4 1.0 0.0492 1.0 0.2634
# 0.6 0.433333333333 1.0 0.0388 1.0 0.2634
# 0.6
# ...

# %% [markdown]
# Or run offline

# %%
hdf5Name = "optimizer.h5"
df = pd.read_hdf(hdf5Name,'table')
#df

# %%
#df

# %%
optimizer.AnalyzePerformanceData(df,tag='bulk',normalize=False)

# %%
optimizer.AnalyzePerformanceData(df,tag='fused',normalize=False)

# %%
fusedThresh=0.85
bulkThresh = 0.5
optimizer.TestParams(fusedThresh=fusedThresh,bulkThresh=bulkThresh,
                     sigma_n=1.,display=True,useFilterInv=True)
# Out:
# 0.85 0.5 0.582763857251 0.0028 0.892494929006 0.0087
# (0.58276385725132873, 0.0028, 0.89249492900608518, 0.0086999999999999994)
