# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import h_n as MyFunc
import cv2
import bankDetect as bD
from scipy.misc import toimage
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:1352: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
def myplot(img,fileName=None):
    plt.axis('equal')
    plt.pcolormesh(img, cmap='gray')
    if fileName!=None:
        plt.gcf().savefig(fileName,dpi=300)
    #plt.axis('off')
    plt.tight_layout()

# %%
fileName = 'clahe_Best.png'
rotation = 5
region =[280,380,60,160]

# %%
bulk, noiseB = MyFunc.doItBulk()
fused, noiseF = MyFunc.doItFused()

# %%
toimage(bulk).save('workFlowBulk.png')
toimage(fused).save('workFlowFused.png')

# %%
imshow(fused)

# %%
noiseB
# Out:
# [10.779646160698517,
#  11.314577829600879,
#  9.8260690770411863,
#  14.202479409792254,
#  16.590189520548634,
#  21.320779325767042,
#  17.042834695786713,
#  15.594481795270209,
#  12.148219743418968,
#  13.572769632705763]

# %%
val = cv2.imread('workFlowFused.png')
myplot(val[:,:,0])

# %%
# fused Pore 
img1 = '/home/AD/srbl226/cleanSpark/sparkdetection/roc/clahe_Best.jpg'
class empty():pass
testCase = empty()
testCase.name = '/home/AD/srbl226/cleanSpark/sparkdetection/roc/clahe_Best.jpg'
testCase.subsection=[275,425,275,425]
daImg = cv2.imread(testCase.name)
cut = daImg[testCase.subsection[0]:testCase.subsection[1],testCase.subsection[2]:testCase.subsection[3]]
imshow(cut)
root = '/home/AD/srbl226/cleanSpark/sparkdetection/roc/'

if 1: 

 dummy = bD.TestFilters(
  img1, # testData
  root+'workFlowFused.png',         # fusedfilter Name
  root+'workFlowBulk.png',        # bulkFilter name
  fusedThresh = 15.,
  bulkThresh = 10.,
  subsection=testCase.subsection,
  display=False
 )
# Out:
# 532.060755556 735.461422222
# rot  0.0 hit 558.6
# 536.077511111
#  732.084977778
# rot 10.0 hit 557.3
# 541.9252
#  729.490311111
# rot 20.0 hit 555.6
# 543.794177778
#  729.997377778
# rot 30.0 hit 554.2
# 543.1592
#  728.681288889
# rot 40.0 hit 553.1
# 543.8916
#  723.846
# rot 50.0 hit 552.1
# 540.762133333
#  720.453866667
# rot 60.0 hit 553.0
# 538.191733333
#  717.620933333
# rot 70.0 hit 555.0
# 540.761688889
#  718.607022222
# rot 80.0 hit 556.1
# 534.818311111
#  719.900133333
# rot 90.0 hit 556.2
# 635.698
#  862.002
# rot  0.0 hit 404.5
# 646.198933333
#  865.646355556
# rot 10.0 hit 407.3
# 653.3464
#  861.680755556
# rot 20.0 hit 407.1
# 667.221422222
#  870.541244444
# rot 30.0 hit 406.1
# 668.400622222
#  874.562088889
# rot 40.0 hit 411.1
# 661.204222222
#  874.878133333
# rot 50.0 hit 408.7
# 668.881822222
#  883.084622222
# rot 60.0 hit 411.1
# 676.704444444
#  885.019955556
# rot 70.0 hit 408.6
# 669.7332
#  890.042711111
# rot 80.0 hit 414.1
# 663.748
# ...
